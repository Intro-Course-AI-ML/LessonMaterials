# %% [markdown]
# <a href="https://colab.research.google.com/github/SiP-AI-ML/LessonMaterials/blob/master/KerasNueralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Nueral Network Practice
# Today, we will built a nueral network in just 10 lines of code. We are going to use very simple data that we don't have to pre-process since it is already in a numerical format. We will go over how to build our model, how to initalize the model, how to train the model, and lastly how to validate its performance.

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# We can now load our dataset.
#
# In this tutorial, we are going to use the Pima Indians onset of diabetes dataset. It describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# As such, it is a binary classification problem (onset of diabetes as 1 or not as 0). All of the input variables that describe each patient are numerical. This makes it easy to use directly with neural networks that expect numerical input and output values, and ideal for our first neural network in Keras.

# %% [markdown]
# [Dataset Link](https://github.com/jbrownlee/Datasets/blob/master/pima-indians-diabetes.csv)

# %% [markdown]
# We can now load the file as a matrix of numbers using the NumPy function loadtxt().
#
# There are eight input variables and one output variable (the last column). We will be learning a model to map rows of input variables (X) to an output variable (y), which we often summarize as y = f(X).
#
# The variables can be summarized as follows:
#
# Input Variables (X):
#
# Number of times pregnant
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# Diastolic blood pressure (mm Hg)
# Triceps skin fold thickness (mm)
# 2-Hour serum insulin (mu U/ml)
# Body mass index (weight in kg/(height in m)^2)
# Diabetes pedigree function
# Age (years)
# Output Variables (y):
#
# Class variable (0 or 1)
# Once the CSV file is loaded into memory, we can split the columns of data into input and output variables.
#
# The data will be stored in a 2D array where the first dimension is rows and the second dimension is columns, e.g. [rows, columns].
#
# We can split the array into two arrays by selecting subsets of columns using the standard NumPy slice operator or “:” We can select the first 8 columns from index 0 to index 7 via the slice 0:8. We can then select the output column (the 9th variable) via index 8.

# %%
# load the dataset
dataset = loadtxt('https://raw.githubusercontent.com/SiP-AI-ML/LessonMaterials/master/pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# Now we will create our basic model. We will use the Keras Sequential Model, just like last time, and we will have 3 layers, also just like last time. The input dimensions are 8, since we have 8 factors that can determine whether they will get diabetes.

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 12)                108
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset, train the model
training = model.fit(X, y, epochs=300, batch_size=10, verbose = 2)
# Out:
# Epoch 1/300
#  - 0s - loss: 0.4874 - accuracy: 0.7721
# Epoch 2/300
#  - 0s - loss: 0.4870 - accuracy: 0.7721
# Epoch 3/300
#  - 0s - loss: 0.4955 - accuracy: 0.7721
# Epoch 4/300
#  - 0s - loss: 0.4775 - accuracy: 0.7695
# Epoch 5/300
#  - 0s - loss: 0.4753 - accuracy: 0.7799
# Epoch 6/300
#  - 0s - loss: 0.4892 - accuracy: 0.7552
# Epoch 7/300
#  - 0s - loss: 0.4954 - accuracy: 0.7552
# Epoch 8/300
#  - 0s - loss: 0.4772 - accuracy: 0.7630
# Epoch 9/300
#  - 0s - loss: 0.4846 - accuracy: 0.7708
# Epoch 10/300
#  - 0s - loss: 0.4847 - accuracy: 0.7617
# Epoch 11/300
#  - 0s - loss: 0.4804 - accuracy: 0.7604
# Epoch 12/300
#  - 0s - loss: 0.4821 - accuracy: 0.7682
# Epoch 13/300
#  - 0s - loss: 0.4823 - accuracy: 0.7773
# Epoch 14/300
#  - 0s - loss: 0.4749 - accuracy: 0.7799
# Epoch 15/300
#  - 0s - loss: 0.4817 - accuracy: 0.7669
# Epoch 16/300
#  - 0s - loss: 0.4894 - accuracy: 0.7526
# Epoch 17/300
#  - 0s - loss: 0.4778 - accuracy: 0.7656
# Epoch 18/300
#  - 0s - loss: 0.4824 - accuracy: 0.7708
# Epoch 19/300
#  - 0s - loss: 0.4851 - accuracy: 0.7656
# Epoch 20/300
#  - 0s - loss: 0.4896 - accuracy: 0.7656
# Epoch 21/300
#  - 0s - loss: 0.4932 - accuracy: 0.7695
# Epoch 22/300
#  - 0s - loss: 0.4939 - accuracy: 0.7552
# Epoch 23/300
#  - 0s - loss: 0.4867 - accuracy: 0.7643
# Epoch 24/300
#  - 0s - loss: 0.4811 - accuracy: 0.7682
# Epoch 25/300
#  - 0s - loss: 0.4772 - accuracy: 0.7760
# Epoch 26/300
#  - 0s - loss: 0.4733 - accuracy: 0.7656
# Epoch 27/300
#  - 0s - loss: 0.4720 - accuracy: 0.7643
# Epoch 28/300
#  - 0s - loss: 0.4735 - accuracy: 0.7617
# Epoch 29/300
#  - 0s - loss: 0.4815 - accuracy: 0.7656
# Epoch 30/300
#  - 0s - loss: 0.4791 - accuracy: 0.7773
# Epoch 31/300
#  - 0s - loss: 0.4772 - accuracy: 0.7695
# Epoch 32/300
#  - 0s - loss: 0.4783 - accuracy: 0.7747
# Epoch 33/300
#  - 0s - loss: 0.4765 - accuracy: 0.7617
# Epoch 34/300
#  - 0s - loss: 0.4693 - accuracy: 0.7826
# Epoch 35/300
#  - 0s - loss: 0.4666 - accuracy: 0.7799
# Epoch 36/300
#  - 0s - loss: 0.4717 - accuracy: 0.7760
# Epoch 37/300
#  - 0s - loss: 0.4738 - accuracy: 0.7852
# Epoch 38/300
#  - 0s - loss: 0.4793 - accuracy: 0.7760
# Epoch 39/300
#  - 0s - loss: 0.4762 - accuracy: 0.7643
# Epoch 40/300
#  - 0s - loss: 0.4755 - accuracy: 0.7734
# Epoch 41/300
#  - 0s - loss: 0.4907 - accuracy: 0.7617
# Epoch 42/300
#  - 0s - loss: 0.4675 - accuracy: 0.7812
# Epoch 43/300
#  - 0s - loss: 0.4671 - accuracy: 0.7747
# Epoch 44/300
#  - 0s - loss: 0.4735 - accuracy: 0.7682
# Epoch 45/300
#  - 0s - loss: 0.4703 - accuracy: 0.7943
# Epoch 46/300
#  - 0s - loss: 0.4710 - accuracy: 0.7760
# Epoch 47/300
#  - 0s - loss: 0.4727 - accuracy: 0.7682
# Epoch 48/300
#  - 0s - loss: 0.4643 - accuracy: 0.7734
# Epoch 49/300
#  - 0s - loss: 0.4619 - accuracy: 0.7708
# Epoch 50/300
#  - 0s - loss: 0.4721 - accuracy: 0.7812
# Epoch 51/300
#  - 0s - loss: 0.4670 - accuracy: 0.7839
# Epoch 52/300
#  - 0s - loss: 0.4671 - accuracy: 0.7799
# Epoch 53/300
#  - 0s - loss: 0.4618 - accuracy: 0.7826
# Epoch 54/300
#  - 0s - loss: 0.4718 - accuracy: 0.7839
# Epoch 55/300
#  - 0s - loss: 0.4712 - accuracy: 0.7682
# Epoch 56/300
#  - 0s - loss: 0.4727 - accuracy: 0.7799
# Epoch 57/300
#  - 0s - loss: 0.4585 - accuracy: 0.7799
# Epoch 58/300
#  - 0s - loss: 0.4654 - accuracy: 0.7708
# Epoch 59/300
#  - 0s - loss: 0.4777 - accuracy: 0.7773
# Epoch 60/300
#  - 0s - loss: 0.4663 - accuracy: 0.7826
# Epoch 61/300
#  - 0s - loss: 0.4742 - accuracy: 0.7734
# Epoch 62/300
#  - 0s - loss: 0.4627 - accuracy: 0.7760
# Epoch 63/300
#  - 0s - loss: 0.4740 - accuracy: 0.7591
# Epoch 64/300
#  - 0s - loss: 0.4718 - accuracy: 0.7630
# Epoch 65/300
#  - 0s - loss: 0.4755 - accuracy: 0.7539
# Epoch 66/300
#  - 0s - loss: 0.4659 - accuracy: 0.7773
# Epoch 67/300
#  - 0s - loss: 0.4612 - accuracy: 0.7760
# Epoch 68/300
#  - 0s - loss: 0.4600 - accuracy: 0.7773
# Epoch 69/300
#  - 0s - loss: 0.4687 - accuracy: 0.7799
# Epoch 70/300
#  - 0s - loss: 0.4669 - accuracy: 0.7747
# Epoch 71/300
#  - 0s - loss: 0.4684 - accuracy: 0.7747
# Epoch 72/300
#  - 0s - loss: 0.4638 - accuracy: 0.7734
# Epoch 73/300
#  - 0s - loss: 0.4654 - accuracy: 0.7812
# Epoch 74/300
#  - 0s - loss: 0.4581 - accuracy: 0.7799
# Epoch 75/300
#  - 0s - loss: 0.4577 - accuracy: 0.7917
# Epoch 76/300
#  - 0s - loss: 0.4641 - accuracy: 0.7747
# Epoch 77/300
#  - 0s - loss: 0.4601 - accuracy: 0.7826
# Epoch 78/300
#  - 0s - loss: 0.4693 - accuracy: 0.7695
# Epoch 79/300
#  - 0s - loss: 0.4573 - accuracy: 0.7852
# Epoch 80/300
#  - 0s - loss: 0.4624 - accuracy: 0.7786
# Epoch 81/300
#  - 0s - loss: 0.4636 - accuracy: 0.7786
# Epoch 82/300
#  - 0s - loss: 0.4621 - accuracy: 0.7865
# Epoch 83/300
#  - 0s - loss: 0.4564 - accuracy: 0.7656
# Epoch 84/300
#  - 0s - loss: 0.4612 - accuracy: 0.7708
# Epoch 85/300
#  - 0s - loss: 0.4614 - accuracy: 0.7878
# Epoch 86/300
#  - 0s - loss: 0.4642 - accuracy: 0.7799
# Epoch 87/300
#  - 0s - loss: 0.4572 - accuracy: 0.7852
# Epoch 88/300
#  - 0s - loss: 0.4663 - accuracy: 0.7786
# Epoch 89/300
#  - 0s - loss: 0.4640 - accuracy: 0.7630
# Epoch 90/300
#  - 0s - loss: 0.4653 - accuracy: 0.7773
# Epoch 91/300
#  - 0s - loss: 0.4613 - accuracy: 0.7734
# Epoch 92/300
#  - 0s - loss: 0.4613 - accuracy: 0.7786
# Epoch 93/300
#  - 0s - loss: 0.4516 - accuracy: 0.7786
# Epoch 94/300
#  - 0s - loss: 0.4607 - accuracy: 0.7786
# Epoch 95/300
#  - 0s - loss: 0.4504 - accuracy: 0.7839
# Epoch 96/300
#  - 0s - loss: 0.4604 - accuracy: 0.7852
# Epoch 97/300
#  - 0s - loss: 0.4539 - accuracy: 0.7904
# Epoch 98/300
#  - 0s - loss: 0.4530 - accuracy: 0.7852
# Epoch 99/300
#  - 0s - loss: 0.4505 - accuracy: 0.7839
# Epoch 100/300
#  - 0s - loss: 0.4579 - accuracy: 0.7799
# Epoch 101/300
#  - 0s - loss: 0.4568 - accuracy: 0.7943
# Epoch 102/300
#  - 0s - loss: 0.4715 - accuracy: 0.7852
# Epoch 103/300
#  - 0s - loss: 0.4550 - accuracy: 0.7826
# Epoch 104/300
#  - 0s - loss: 0.4706 - accuracy: 0.7773
# Epoch 105/300
#  - 0s - loss: 0.4530 - accuracy: 0.7839
# Epoch 106/300
#  - 0s - loss: 0.4591 - accuracy: 0.7773
# Epoch 107/300
#  - 0s - loss: 0.4673 - accuracy: 0.7786
# Epoch 108/300
#  - 0s - loss: 0.4580 - accuracy: 0.7773
# Epoch 109/300
#  - 0s - loss: 0.4474 - accuracy: 0.7799
# Epoch 110/300
#  - 0s - loss: 0.4529 - accuracy: 0.8047
# Epoch 111/300
#  - 0s - loss: 0.4537 - accuracy: 0.7786
# Epoch 112/300
#  - 0s - loss: 0.4584 - accuracy: 0.7812
# Epoch 113/300
#  - 0s - loss: 0.4576 - accuracy: 0.7943
# Epoch 114/300
#  - 0s - loss: 0.4537 - accuracy: 0.7839
# Epoch 115/300
#  - 0s - loss: 0.4500 - accuracy: 0.7878
# Epoch 116/300
#  - 0s - loss: 0.4502 - accuracy: 0.7812
# Epoch 117/300
#  - 0s - loss: 0.4546 - accuracy: 0.7865
# Epoch 118/300
#  - 0s - loss: 0.4469 - accuracy: 0.7760
# Epoch 119/300
#  - 0s - loss: 0.4429 - accuracy: 0.7865
# Epoch 120/300
#  - 0s - loss: 0.4448 - accuracy: 0.7865
# Epoch 121/300
#  - 0s - loss: 0.4506 - accuracy: 0.7786
# Epoch 122/300
#  - 0s - loss: 0.4517 - accuracy: 0.7917
# Epoch 123/300
#  - 0s - loss: 0.4507 - accuracy: 0.7891
# Epoch 124/300
#  - 0s - loss: 0.4684 - accuracy: 0.7760
# Epoch 125/300
#  - 0s - loss: 0.4416 - accuracy: 0.7839
# Epoch 126/300
#  - 0s - loss: 0.4581 - accuracy: 0.7917
# Epoch 127/300
#  - 0s - loss: 0.4434 - accuracy: 0.7982
# Epoch 128/300
#  - 0s - loss: 0.4483 - accuracy: 0.7786
# Epoch 129/300
#  - 0s - loss: 0.4476 - accuracy: 0.7812
# Epoch 130/300
#  - 0s - loss: 0.4451 - accuracy: 0.7839
# Epoch 131/300
#  - 0s - loss: 0.4585 - accuracy: 0.7839
# Epoch 132/300
#  - 0s - loss: 0.4484 - accuracy: 0.7839
# Epoch 133/300
#  - 0s - loss: 0.4543 - accuracy: 0.7852
# Epoch 134/300
#  - 0s - loss: 0.4453 - accuracy: 0.7760
# Epoch 135/300
#  - 0s - loss: 0.4449 - accuracy: 0.7865
# Epoch 136/300
#  - 0s - loss: 0.4433 - accuracy: 0.7839
# Epoch 137/300
#  - 0s - loss: 0.4566 - accuracy: 0.7930
# Epoch 138/300
#  - 0s - loss: 0.4375 - accuracy: 0.7891
# Epoch 139/300
#  - 0s - loss: 0.4493 - accuracy: 0.7812
# Epoch 140/300
#  - 0s - loss: 0.4462 - accuracy: 0.7865
# Epoch 141/300
#  - 0s - loss: 0.4455 - accuracy: 0.7904
# Epoch 142/300
#  - 0s - loss: 0.4474 - accuracy: 0.7865
# Epoch 143/300
#  - 0s - loss: 0.4413 - accuracy: 0.7930
# Epoch 144/300
#  - 0s - loss: 0.4587 - accuracy: 0.7760
# Epoch 145/300
#  - 0s - loss: 0.4392 - accuracy: 0.7799
# Epoch 146/300
#  - 0s - loss: 0.4371 - accuracy: 0.7969
# Epoch 147/300
#  - 0s - loss: 0.4668 - accuracy: 0.7669
# Epoch 148/300
#  - 0s - loss: 0.4455 - accuracy: 0.7826
# Epoch 149/300
#  - 0s - loss: 0.4551 - accuracy: 0.7930
# Epoch 150/300
#  - 0s - loss: 0.4477 - accuracy: 0.7852
# Epoch 151/300
#  - 0s - loss: 0.4496 - accuracy: 0.7865
# Epoch 152/300
#  - 0s - loss: 0.4474 - accuracy: 0.7852
# Epoch 153/300
#  - 0s - loss: 0.4486 - accuracy: 0.7839
# Epoch 154/300
#  - 0s - loss: 0.4476 - accuracy: 0.7760
# Epoch 155/300
#  - 0s - loss: 0.4374 - accuracy: 0.7930
# Epoch 156/300
#  - 0s - loss: 0.4431 - accuracy: 0.7878
# Epoch 157/300
#  - 0s - loss: 0.4368 - accuracy: 0.7956
# Epoch 158/300
#  - 0s - loss: 0.4381 - accuracy: 0.7878
# Epoch 159/300
#  - 0s - loss: 0.4356 - accuracy: 0.7943
# Epoch 160/300
#  - 0s - loss: 0.4445 - accuracy: 0.7865
# Epoch 161/300
#  - 0s - loss: 0.4490 - accuracy: 0.7695
# Epoch 162/300
#  - 0s - loss: 0.4438 - accuracy: 0.7839
# Epoch 163/300
#  - 0s - loss: 0.4488 - accuracy: 0.7812
# Epoch 164/300
#  - 0s - loss: 0.4668 - accuracy: 0.7956
# Epoch 165/300
#  - 0s - loss: 0.4347 - accuracy: 0.8008
# Epoch 166/300
#  - 0s - loss: 0.4476 - accuracy: 0.7773
# Epoch 167/300
#  - 0s - loss: 0.4428 - accuracy: 0.7878
# Epoch 168/300
#  - 0s - loss: 0.4458 - accuracy: 0.7721
# Epoch 169/300
#  - 0s - loss: 0.4505 - accuracy: 0.7773
# Epoch 170/300
#  - 0s - loss: 0.4417 - accuracy: 0.7865
# Epoch 171/300
#  - 0s - loss: 0.4412 - accuracy: 0.7904
# Epoch 172/300
#  - 0s - loss: 0.4406 - accuracy: 0.7878
# Epoch 173/300
#  - 0s - loss: 0.4408 - accuracy: 0.7930
# Epoch 174/300
#  - 0s - loss: 0.4553 - accuracy: 0.7656
# Epoch 175/300
#  - 0s - loss: 0.4317 - accuracy: 0.7982
# Epoch 176/300
#  - 0s - loss: 0.4335 - accuracy: 0.8008
# Epoch 177/300
#  - 0s - loss: 0.4642 - accuracy: 0.7773
# Epoch 178/300
#  - 0s - loss: 0.4536 - accuracy: 0.7852
# Epoch 179/300
#  - 0s - loss: 0.4314 - accuracy: 0.7839
# Epoch 180/300
#  - 0s - loss: 0.4367 - accuracy: 0.8086
# Epoch 181/300
#  - 0s - loss: 0.4378 - accuracy: 0.7878
# Epoch 182/300
#  - 0s - loss: 0.4314 - accuracy: 0.7956
# Epoch 183/300
#  - 0s - loss: 0.4373 - accuracy: 0.7786
# Epoch 184/300
#  - 0s - loss: 0.4253 - accuracy: 0.7943
# Epoch 185/300
#  - 0s - loss: 0.4323 - accuracy: 0.7799
# Epoch 186/300
#  - 0s - loss: 0.4332 - accuracy: 0.8021
# Epoch 187/300
#  - 0s - loss: 0.4463 - accuracy: 0.7799
# Epoch 188/300
#  - 0s - loss: 0.4439 - accuracy: 0.7760
# Epoch 189/300
#  - 0s - loss: 0.4465 - accuracy: 0.7878
# Epoch 190/300
#  - 0s - loss: 0.4523 - accuracy: 0.7904
# Epoch 191/300
#  - 0s - loss: 0.4408 - accuracy: 0.7812
# Epoch 192/300
#  - 0s - loss: 0.4323 - accuracy: 0.7865
# Epoch 193/300
#  - 0s - loss: 0.4377 - accuracy: 0.7930
# Epoch 194/300
#  - 0s - loss: 0.4342 - accuracy: 0.7943
# Epoch 195/300
#  - 0s - loss: 0.4369 - accuracy: 0.7904
# Epoch 196/300
#  - 0s - loss: 0.4361 - accuracy: 0.8021
# Epoch 197/300
#  - 0s - loss: 0.4332 - accuracy: 0.7982
# Epoch 198/300
#  - 0s - loss: 0.4398 - accuracy: 0.7839
# Epoch 199/300
#  - 0s - loss: 0.4363 - accuracy: 0.7839
# Epoch 200/300
#  - 0s - loss: 0.4384 - accuracy: 0.7917
# Epoch 201/300
#  - 0s - loss: 0.4356 - accuracy: 0.7852
# Epoch 202/300
#  - 0s - loss: 0.4408 - accuracy: 0.7878
# Epoch 203/300
#  - 0s - loss: 0.4388 - accuracy: 0.7773
# Epoch 204/300
#  - 0s - loss: 0.4419 - accuracy: 0.7839
# Epoch 205/300
#  - 0s - loss: 0.4303 - accuracy: 0.7982
# Epoch 206/300
#  - 0s - loss: 0.4450 - accuracy: 0.7943
# Epoch 207/300
#  - 0s - loss: 0.4457 - accuracy: 0.7826
# Epoch 208/300
#  - 0s - loss: 0.4320 - accuracy: 0.7891
# Epoch 209/300
#  - 0s - loss: 0.4363 - accuracy: 0.7891
# Epoch 210/300
#  - 0s - loss: 0.4470 - accuracy: 0.7812
# Epoch 211/300
#  - 0s - loss: 0.4321 - accuracy: 0.7839
# Epoch 212/300
#  - 0s - loss: 0.4286 - accuracy: 0.7904
# Epoch 213/300
#  - 0s - loss: 0.4323 - accuracy: 0.7904
# Epoch 214/300
#  - 0s - loss: 0.4264 - accuracy: 0.7943
# Epoch 215/300
#  - 0s - loss: 0.4394 - accuracy: 0.7943
# Epoch 216/300
#  - 0s - loss: 0.4288 - accuracy: 0.7930
# Epoch 217/300
#  - 0s - loss: 0.4241 - accuracy: 0.8047
# Epoch 218/300
#  - 0s - loss: 0.4316 - accuracy: 0.7943
# Epoch 219/300
#  - 0s - loss: 0.4265 - accuracy: 0.7852
# Epoch 220/300
#  - 0s - loss: 0.4230 - accuracy: 0.7930
# Epoch 221/300
#  - 0s - loss: 0.4216 - accuracy: 0.8034
# Epoch 222/300
#  - 0s - loss: 0.4370 - accuracy: 0.7982
# Epoch 223/300
#  - 0s - loss: 0.4350 - accuracy: 0.7878
# Epoch 224/300
#  - 0s - loss: 0.4437 - accuracy: 0.7826
# Epoch 225/300
#  - 0s - loss: 0.4257 - accuracy: 0.7956
# Epoch 226/300
#  - 0s - loss: 0.4342 - accuracy: 0.7995
# Epoch 227/300
#  - 0s - loss: 0.4278 - accuracy: 0.7891
# Epoch 228/300
#  - 0s - loss: 0.4260 - accuracy: 0.7930
# Epoch 229/300
#  - 0s - loss: 0.4233 - accuracy: 0.7891
# Epoch 230/300
#  - 0s - loss: 0.4225 - accuracy: 0.7943
# Epoch 231/300
#  - 0s - loss: 0.4323 - accuracy: 0.7943
# Epoch 232/300
#  - 0s - loss: 0.4322 - accuracy: 0.7904
# Epoch 233/300
#  - 0s - loss: 0.4307 - accuracy: 0.7852
# Epoch 234/300
#  - 0s - loss: 0.4232 - accuracy: 0.8021
# Epoch 235/300
#  - 0s - loss: 0.4293 - accuracy: 0.7904
# Epoch 236/300
#  - 0s - loss: 0.4237 - accuracy: 0.8008
# Epoch 237/300
#  - 0s - loss: 0.4396 - accuracy: 0.7904
# Epoch 238/300
#  - 0s - loss: 0.4378 - accuracy: 0.7904
# Epoch 239/300
#  - 0s - loss: 0.4343 - accuracy: 0.7930
# Epoch 240/300
#  - 0s - loss: 0.4226 - accuracy: 0.7982
# Epoch 241/300
#  - 0s - loss: 0.4290 - accuracy: 0.7943
# Epoch 242/300
#  - 0s - loss: 0.4181 - accuracy: 0.8034
# Epoch 243/300
#  - 0s - loss: 0.4272 - accuracy: 0.7956
# Epoch 244/300
#  - 0s - loss: 0.4362 - accuracy: 0.7943
# Epoch 245/300
#  - 0s - loss: 0.4328 - accuracy: 0.7969
# Epoch 246/300
#  - 0s - loss: 0.4334 - accuracy: 0.7878
# Epoch 247/300
#  - 0s - loss: 0.4309 - accuracy: 0.7839
# Epoch 248/300
#  - 0s - loss: 0.4377 - accuracy: 0.7839
# Epoch 249/300
#  - 0s - loss: 0.4373 - accuracy: 0.7943
# Epoch 250/300
#  - 0s - loss: 0.4242 - accuracy: 0.7943
# Epoch 251/300
#  - 0s - loss: 0.4473 - accuracy: 0.8021
# Epoch 252/300
#  - 0s - loss: 0.4379 - accuracy: 0.7904
# Epoch 253/300
#  - 0s - loss: 0.4291 - accuracy: 0.7956
# Epoch 254/300
#  - 0s - loss: 0.4261 - accuracy: 0.7891
# Epoch 255/300
#  - 0s - loss: 0.4243 - accuracy: 0.7904
# Epoch 256/300
#  - 0s - loss: 0.4419 - accuracy: 0.7982
# Epoch 257/300
#  - 0s - loss: 0.4319 - accuracy: 0.7904
# Epoch 258/300
#  - 0s - loss: 0.4272 - accuracy: 0.8086
# Epoch 259/300
#  - 0s - loss: 0.4161 - accuracy: 0.8034
# Epoch 260/300
#  - 0s - loss: 0.4429 - accuracy: 0.7773
# Epoch 261/300
#  - 0s - loss: 0.4264 - accuracy: 0.7943
# Epoch 262/300
#  - 0s - loss: 0.4287 - accuracy: 0.8073
# Epoch 263/300
#  - 0s - loss: 0.4169 - accuracy: 0.7956
# Epoch 264/300
#  - 0s - loss: 0.4338 - accuracy: 0.7982
# Epoch 265/300
#  - 0s - loss: 0.4252 - accuracy: 0.7956
# Epoch 266/300
#  - 0s - loss: 0.4356 - accuracy: 0.7904
# Epoch 267/300
#  - 0s - loss: 0.4276 - accuracy: 0.7904
# Epoch 268/300
#  - 0s - loss: 0.4214 - accuracy: 0.7956
# Epoch 269/300
#  - 0s - loss: 0.4282 - accuracy: 0.7982
# Epoch 270/300
#  - 0s - loss: 0.4185 - accuracy: 0.7943
# Epoch 271/300
#  - 0s - loss: 0.4190 - accuracy: 0.7956
# Epoch 272/300
#  - 0s - loss: 0.4260 - accuracy: 0.7943
# Epoch 273/300
#  - 0s - loss: 0.4201 - accuracy: 0.7982
# Epoch 274/300
#  - 0s - loss: 0.4187 - accuracy: 0.7982
# Epoch 275/300
#  - 0s - loss: 0.4198 - accuracy: 0.8034
# Epoch 276/300
#  - 0s - loss: 0.4241 - accuracy: 0.7982
# Epoch 277/300
#  - 0s - loss: 0.4329 - accuracy: 0.7943
# Epoch 278/300
#  - 0s - loss: 0.4174 - accuracy: 0.8008
# Epoch 279/300
#  - 0s - loss: 0.4245 - accuracy: 0.8008
# Epoch 280/300
#  - 0s - loss: 0.4350 - accuracy: 0.7891
# Epoch 281/300
#  - 0s - loss: 0.4155 - accuracy: 0.7969
# Epoch 282/300
#  - 0s - loss: 0.4171 - accuracy: 0.8021
# Epoch 283/300
#  - 0s - loss: 0.4208 - accuracy: 0.7930
# Epoch 284/300
#  - 0s - loss: 0.4228 - accuracy: 0.8034
# Epoch 285/300
#  - 0s - loss: 0.4306 - accuracy: 0.7956
# Epoch 286/300
#  - 0s - loss: 0.4297 - accuracy: 0.7865
# Epoch 287/300
#  - 0s - loss: 0.4167 - accuracy: 0.8047
# Epoch 288/300
#  - 0s - loss: 0.4158 - accuracy: 0.7943
# Epoch 289/300
#  - 0s - loss: 0.4175 - accuracy: 0.8073
# Epoch 290/300
#  - 0s - loss: 0.4271 - accuracy: 0.8177
# Epoch 291/300
#  - 0s - loss: 0.4228 - accuracy: 0.7891
# Epoch 292/300
#  - 0s - loss: 0.4279 - accuracy: 0.7917
# Epoch 293/300
#  - 0s - loss: 0.4140 - accuracy: 0.8112
# Epoch 294/300
#  - 0s - loss: 0.4261 - accuracy: 0.7969
# Epoch 295/300
#  - 0s - loss: 0.4201 - accuracy: 0.7891
# Epoch 296/300
#  - 0s - loss: 0.4210 - accuracy: 0.7982
# Epoch 297/300
#  - 0s - loss: 0.4155 - accuracy: 0.8008
# Epoch 298/300
#  - 0s - loss: 0.4141 - accuracy: 0.7891
# Epoch 299/300
#  - 0s - loss: 0.4239 - accuracy: 0.7904
# Epoch 300/300
#  - 0s - loss: 0.4288 - accuracy: 0.8047

# %%
# now lets see how the accuracy of our model increased over training.
# summarize history for accuracy
plt.plot(training.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.show()

# %%
# now lets see how the loss of our model progressed over training.
plt.plot(training.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.show()

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print(model.evaluate(X,y))
print(accuracy * 100)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 35us/step
# 768/768 [==============================] - 0s 26us/step
# [0.41956742852926254, 0.8033854365348816]
# 80.33854365348816
# Accuracy: 80.34

# %% [markdown]
# What score did you get?
# Post your results in the zoom chat.
#
# Neural networks are a stochastic algorithm, meaning that the same algorithm on the same data can train a different model with different skill each time the code is run. This is a feature, not a bug.
#
# This model won't perform very well since the architecture is not very good. However, it is a very simple architecture, meaning it is a good place to start and learn from.
