# %% [markdown]
# <a href="https://colab.research.google.com/github/SiP-AI-ML/LessonMaterials/blob/master/classLinRegModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
